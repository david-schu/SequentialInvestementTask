# %%
# %load_ext autoreload

# %autoreload 2

import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from utils import load_data_patient as load_data, generate_subject_table
from GeneralizedQ import GaussianProcess as GP
from scipy.stats import chi2_contingency, pearsonr, zscore
from scipy.stats.contingency import margins
from scipy.special import softmax
import pandas as pd
from pandas.plotting import table
import dataframe_image as dfi
import matplotlib.patches as mpatches
from sklearn import linear_model, mixture, cluster
import seaborn as sns
import utils
from tqdm import tqdm
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

titlesize = 10
fontsize = 8
cm = 1/2.54
figwidth = 14.7*cm
dpi = 600
params = {'legend.fontsize': fontsize,
          'legend.title_fontsize': fontsize,
          'font.family': 'serif',
         'axes.labelsize': fontsize,
         'axes.titlesize':titlesize,
         'xtick.labelsize':fontsize,
         'ytick.labelsize':fontsize}
plt.rcParams.update(params)

def tab_name_to_hex(tab): 
    conv_table = {
        "tab:blue": "#1f77b4",
        "tab:orange": "#ff7f0e",
        "tab:green": "#2ca02c",
        "tab:red": "#d62728",
        "tab:purple": "#9467bd",
        "tab:brown": "#8c564b",
        "tab:pink": "#e377c2",
        "tab:gray": "#7f7f7f",
        "tab:grey": "#7f7f7f",
        "tab:olive": "#bcbd22",
        "tab:cyan": "#17becf",
    }
    return conv_table[tab.lower()]

plot_colors = [tab_name_to_hex('tab:blue'), 
               tab_name_to_hex('tab:red'), 
               tab_name_to_hex('tab:green'), 
               tab_name_to_hex('tab:orange'), 
               tab_name_to_hex('tab:purple'), 
               tab_name_to_hex('tab:brown'), 
               tab_name_to_hex('tab:pink'), 
               tab_name_to_hex('tab:gray'), 
               tab_name_to_hex('tab:olive'), 
               tab_name_to_hex('tab:cyan')] 

two_colors = ['darkred', 'tab:red']
# Out:
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/compat/pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
def chi_square(c_data, index):
    
    chi_squares = {}
    
    # portfolio delta
    chi_squares['d_portfolio'] = chi2_contingency(pd.crosstab(np.sign(c_data['d_portfolio']), np.sign(c_data['d_bet'])))[0]
    
    # market delta
    chi_squares['d_market'] = chi2_contingency(pd.crosstab(np.sign(c_data['d_market']), np.sign(c_data['d_bet'])))[0]
    
    # market delta
    chi_squares['d_market_belief'] = chi2_contingency(pd.crosstab(np.sign(c_data['d_market_belief']), np.sign(c_data['d_bet'])))[0]
    

    chi_squares = pd.DataFrame(chi_squares, index=[index])
    
#     if index == 0:
#         dfi.export(pd.crosstab(np.sign(c_data['d_portfolio']), np.sign(c_data['d_bet'])), 'crosstan_d_portfolio.png')
#         dfi.export(pd.crosstab(np.sign(c_data['d_market']), np.sign(c_data['d_bet'])), 'crosstan_d_market.png')
#         dfi.export(pd.crosstab(np.sign(c_data['d_market_belief']), np.sign(c_data['d_bet'])), 'crosstan_d_market_belief.png')        
#         dfi.export(pd.crosstab(bet_size, np.sign(c_data['d_bet'])), 'crosstab_counterfactual_regret.png')  
#         dfi.export(chi_squares.reindex(index=['chi_square']), 'chi_square.png')
    
    return chi_squares

def pearsonr_pval(x,y):
        return pearsonr(x,y)[1]

# %% [markdown]
# # Load data

# %%
data = load_data('all')
all_data = pd.DataFrame()

for i, subject in enumerate(data):
    subject['subj'] = i
    all_data = pd.concat([all_data, subject])
all_data.index = np.arange(len(all_data))

# %%
abs(all_data['d_portfolio']).mean()
# Out:
# 2.8070662468391507

# %% [markdown]
# # Show distribution of bet changes

# %%
fig, ax = plt.subplots(2,1,figsize=(figwidth/2, 4), dpi=200)
weights = np.ones(len(all_data))/float(len(all_data))

ax[0].hist(all_data['bet'], bins=np.linspace(-5,105,12), rwidth=.7, weights=weights, color=plot_colors[1])
ax[0].set_xlabel('bet size')
ax[0].set_ylabel('% trials')

ax[1].hist(all_data['d_bet'], bins=np.linspace(-105,105,22), rwidth=.7, weights=weights, color=plot_colors[1])
ax[1].set_xlabel('$\Delta$ bet')
ax[1].set_ylabel('% trials')
plt.tight_layout()
plt.savefig('figures/dists_healthy.png')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(figwidth/2.5, 1.5), dpi=200)
bins = np.linspace(-105,105,22)
freqs = np.zeros((11, 21))
for i, bet in enumerate(np.arange(0, 101,10)):
    d_bets = all_data['d_bet'][all_data['bet']==bet]
    freqs[i] = np.histogram(d_bets, bins=bins)[0]
    freqs[i] /= freqs[i].sum()
sns.heatmap(freqs, xticklabels=[int(x) for x in np.linspace(-100,100,21)], yticklabels=[int(x) for x in np.linspace(0,100,11)])
plt.xlabel('d_bet')
plt.xticks(np.arange(0,21,5)+.5)
plt.yticks(np.arange(0,11,2)+.5)
plt.ylabel('bet size')
# Out:
# Text(5.318460192475939, 0.5, 'bet size')

# %% [markdown]
# # Clustering subjects betsizes

# %%
bet_data = pd.crosstab(all_data['subj'], all_data['bet'])

all_preds = np.zeros((100,21))
for seed in tqdm(range(100)):
    np.random.seed(seed)

    lowest_bic = np.infty
    bic = []
    
    for n_components in range(1, 4):
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(
            n_init=1000,
            n_components=n_components, 
            reg_covar=1,
            init_params='random'
        )
        gmm.fit(bet_data)
        bic.append(gmm.bic(bet_data))
        if bic[-1] < lowest_bic and bic[-1]>0:
            lowest_bic = bic[-1]
            best_gmm = gmm

    preds = best_gmm.predict(bet_data)
    all_preds[seed] = preds
# Out:
# 100%|██████████| 100/100 [23:57<00:00, 14.38s/it]

# %%
all_preds_ = abs(all_preds-all_preds[:,2].reshape((-1,1)))
plt.figure(figsize=(figwidth/1.5,3), dpi=200)
sns.heatmap(all_preds_.T, cbar=False)
plt.ylabel('subject')
plt.xlabel('seed')

preds = np.zeros(21)-1

for i, p in enumerate(all_preds_.T):
    u, count = np.unique(p, return_counts=True)
    if count.max() > 90:
        preds[i] = u[np.argmax(count)]
    else:
        preds[i] = 2

# %%
np.save('data/clusters.npy', preds)

# %%
preds = np.load('data/clusters.npy')
n = 3# len(best_gmm.means_)
fig, ax = plt.subplots(n,1, figsize=(figwidth/2,n*2), dpi=200, sharey=True, sharex=True)

for i in range(n):

    ax[i].bar(np.arange(0,101,10), bet_data[preds==i].sum(axis=0)/bet_data[preds==i].sum().sum(), width=7)
    ax[i].legend(['Cluster %d, n = %d' % (i+1, (preds==i).sum())], loc='upper center')
    ax[i].set_ylabel('% observations')

plt.tight_layout()
plt.xlabel('bet size')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8449679936bb> in <module>
#       5 for i in range(n):
#       6
# ----> 7     ax[i].bar(np.arange(0,101,10), bet_data[preds==i].sum(axis=0)/bet_data[preds==i].sum().sum(), width=7)
#       8     ax[i].legend(['Cluster %d, n = %d' % (i+1, (preds==i).sum())], loc='upper center')
#       9     ax[i].set_ylabel('% observations')
#
# NameError: name 'bet_data' is not defined

# %%
data = load_data('all')
fig, axs = plt.subplots(2,1, figsize=(figwidth/2,4), dpi=200)

bins = np.linspace(-105,105,22)
freqs = []

for pred in range(n):
    for i, subject in enumerate(data):
        if preds[i] == pred:
            d_bets = subject['d_bet']
            freq = np.histogram(d_bets, bins=bins)[0]
            freqs.append(freq/freq.sum())

    
for i in range(n-1):
    n_class =(preds<=i).sum()
    axs[0].hlines(n_class,0,21, color='white')
    
sns.heatmap(freqs, xticklabels=[int(x) for x in np.linspace(-100,100,21)], ax=axs[0])
axs[0].set_xlabel('d_bet')
axs[0].set_xticks(np.arange(0,21,5)+.5)
axs[0].set_ylabel('subject')
axs[0].tick_params(axis='x', labelrotation=0)


bins = np.linspace(-5,105,12)
freqs = []
for pred in range(n):
    for i, subject in enumerate(data):
        if preds[i] == pred:
            d_bets = subject['bet']
            freq = np.histogram(d_bets, bins=bins)[0]
            if i == 17:
                print(freq)
            freqs.append(freq/freq.sum())

    
for i in range(n-1):
    n_class =(preds<=i).sum()
    axs[1].hlines(n_class,0,21, color='white')

sns.heatmap(freqs, xticklabels=[int(x) for x in np.linspace(0,100,11)], ax=axs[1])
axs[1].set_xlabel('bet size')
axs[1].set_ylabel('subject')
axs[1].set_xticks(np.arange(0,11,2)+.5)
axs[1].tick_params(axis='x', labelrotation=0)
plt.tight_layout()
plt.show()
# Out:
# [46 10  5  3  4  6 15  5  4 12 10]

# %% [markdown]
# # Look at contigencies

# %%
data = load_data('all')
correlations = pd.DataFrame()
chi_squares = pd.DataFrame()

for i, subject in enumerate(data):
    chi_squares = pd.concat([chi_squares, chi_square(subject, i)])

    corr_coeff = pd.DataFrame(subject.corr(method ='pearson')['d_bet']).T
    corr_coeff['metric'] = 'corr'
    correlations = pd.concat([correlations, corr_coeff])
    
    p_coeff = pd.DataFrame(subject.corr(method=pearsonr_pval)['d_bet']).T
    p_coeff['metric'] = 'p value'
    correlations = pd.concat([correlations, p_coeff])
    
correlations.index = np.arange(len(correlations))
    
# correlations = correlations.drop(columns='d_bet')
# dfi.export(corr_coeff, 'dataframe.png')
# Out:
# /home/lu/.local/lib/python3.8/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/lu/.local/lib/python3.8/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/lu/.local/lib/python3.8/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
f, (a0, a1) = plt.subplots(1,2, figsize=(12,3), gridspec_kw={'width_ratios': [1.5, 3]}, dpi=200)

props = {'color': 'k'}
chi_squares.drop(columns=['d_market']).boxplot(notch=True, boxprops=props, medianprops=props, whiskerprops=props, capprops=props, whis=[5,95], showfliers=False, ax=a0, widths=.2)
a0.set_xticklabels(a0.get_xticklabels(), rotation=45, ha='right')
a0.grid(False)

a0.set_ylabel('chi square')
a0.set_xlabel('(a)')
a0.xaxis.set_label_coords(.5, -.6)

props = {'color': 'tab:blue'}
correlations.loc[correlations['metric']=='corr'][['d_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']].boxplot(notch=True,positions=np.arange(6)*2-0.3, widths=.4, boxprops=props, medianprops=props, whiskerprops=props, capprops=props, whis=[5,95], showfliers=False, ax=a1)


props = {'color': 'tab:orange'}
correlations.loc[correlations['metric']=='p value'][['d_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']].boxplot(notch=True,positions=np.arange(6)*2+0.3, widths=.4, boxprops=props, medianprops=props, whiskerprops=props, capprops=props, whis=[5,95], showfliers=False, ax=a1)

a1.grid(False)
a1.hlines(0, -1, 11, 'k', linestyles='dashed')
a1.hlines(0.05, -1, 11, color='tab:orange')


a1.legend(handles=[mpatches.Patch(color='tab:blue', label='correlation'), mpatches.Patch(color='tab:orange', label='p value')])
a1.set_xticks(np.arange(6)*2,)
a1.set_xticklabels(['d_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret'], rotation=45, ha='right')
a1.set_xlabel('(b)')
a1.xaxis.set_label_coords(.5, -.6)

plt.show()

# %% [markdown]
# # Linear Regression

# %%
regression_results= pd.DataFrame()
p_values = pd.DataFrame()

data = load_data('all')
for i, subject in enumerate(tqdm(data)):

    for column in subject.columns:
        if abs(subject[column]).sum()>0:
            subject[column] = zscore(subject[column], nan_policy='omit')
    
    md = sm.OLS.from_formula('d_bet ~ 0 + bet + d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_rejoice + counterfactual_regret', subject, missing='drop')
    result = md.fit()
    
    res = result.params
    res['ll'] = result.llf
    res['bic'] = result.bic
    
    regression_results = regression_results.append(res, ignore_index=True)
    p_values= p_values.append(result.pvalues, ignore_index=True)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 22.22it/s]

# %%
fig, ax = plt.subplots(1,1, figsize=(figwidth,3), dpi=300, sharey=True, sharex=True)

plt.figure(dpi=400)
props = {'color': 'tab:blue'}
plot_params = regression_results[['bet', 'd_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']]
plot_params.boxplot(notch=True,positions=np.arange(len(plot_params.columns))*2-0.3, widths=.4, medianprops=props, capprops=props, whis=[5,95], showfliers=False, ax=ax)

props = {'color': 'tab:orange'}
plot_p = p_values[['bet', 'd_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']]
plot_p.boxplot(notch=True,positions=np.arange(len(plot_params.columns))*2+0.3, widths=.4, boxprops=props, medianprops=props, whiskerprops=props, capprops=props, whis=[5,95], showfliers=False, ax = ax)

ax.grid(False)
ax.hlines(0, -0.5, len(plot_params.columns)*2, 'k', linestyles='dashed')
ax.set_xticks(np.arange(len(plot_params.columns))*2,)
ax.set_xticklabels(plot_params.columns, rotation=45, ha="right")
ax.legend(handles=[mpatches.Patch(color='tab:blue', label='coefficient'), mpatches.Patch(color='tab:orange', label='p_value')])
ax.hlines(0.05, -0.5, len(plot_params.columns)*2, 'tab:orange')


plt.show()

# %%
regression_results_cluster1 = pd.DataFrame()
regression_results_cluster2 = pd.DataFrame()

data = load_data('all')
for i, subject in enumerate(tqdm(data)):

    for column in subject.columns:
        if abs(subject[column]).sum()>0:
            subject[column] = zscore(subject[column], nan_policy='omit')
    
    md = sm.OLS.from_formula('d_bet ~ 0 + bet + d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_rejoice + counterfactual_regret', subject, missing='drop')
    result = md.fit()
    
    res = result.params
    
    if preds[i] == 0:
        regression_results_cluster1 = regression_results_cluster1.append(res, ignore_index=True)
    elif preds[i] == 1:
        regression_results_cluster2 = regression_results_cluster2.append(res, ignore_index=True)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 35.40it/s]

# %%
fig, ax = plt.subplots(figsize=(figwidth,4), dpi=300, sharey=True, sharex=True)
err = [regression_results_cluster1.std(), regression_results_cluster2.std()]
pd.DataFrame({'C1': regression_results_cluster1.mean(), 'C2': regression_results_cluster2.mean()}).plot(kind='bar', ax=ax, color=two_colors, yerr=err)
plt.xticks(ha='right', rotation=45)
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth,2), dpi=300, sharey=True, sharex=True)

plt.figure(dpi=400)
props = {'color': 'tab:blue'}
plot_params = regression_results_cluster1[['bet', 'd_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']]
plot_params.boxplot(notch=True,positions=np.arange(len(plot_params.columns))*2-0.3, widths=.4, medianprops=props, capprops=props, whis=[5,95], showfliers=False, ax=ax[0])

props = {'color': 'tab:orange'}
plot_p = p_values_cluster1[['bet', 'd_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']]
plot_p.boxplot(notch=True,positions=np.arange(len(plot_params.columns))*2+0.3, widths=.4, boxprops=props, medianprops=props, whiskerprops=props, capprops=props, whis=[5,95], showfliers=False, ax = ax[0])

ax[0].grid(False)
ax[0].hlines(0, -0.5, len(plot_params.columns)*2, 'k', linestyles='dashed')
ax[0].set_xticks(np.arange(len(plot_params.columns))*2,)
ax[0].set_xticklabels(plot_params.columns, rotation=45, ha="right")
ax[0].legend(handles=[mpatches.Patch(color='tab:blue', label='coefficient'), mpatches.Patch(color='tab:orange', label='p_value')])
ax[0].hlines(0.05, -0.5, len(plot_params.columns)*2, 'tab:orange')

ax[0].set_ylim(-1,1)

plt.figure(dpi=400)
props = {'color': 'tab:blue'}
plot_params = regression_results_cluster2[['bet', 'd_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']]
plot_params.boxplot(notch=True,positions=np.arange(len(plot_params.columns))*2-0.3, widths=.4, medianprops=props, capprops=props, whis=[5,95], showfliers=False, ax=ax[1])

props = {'color': 'tab:orange'}
plot_p = p_values_cluster2[['bet', 'd_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']]
plot_p.boxplot(notch=True,positions=np.arange(len(plot_params.columns))*2+0.3, widths=.4, boxprops=props, medianprops=props, whiskerprops=props, capprops=props, whis=[5,95], showfliers=False, ax = ax[1])

ax[1].grid(False)
ax[1].hlines(0, -0.5, len(plot_params.columns)*2, 'k', linestyles='dashed')
ax[1].set_xticks(np.arange(len(plot_params.columns))*2,)
ax[1].set_xticklabels(plot_params.columns, rotation=45, ha="right")
ax[1].legend(handles=[mpatches.Patch(color='tab:blue', label='coefficient'), mpatches.Patch(color='tab:orange', label='p_value')])
ax[1].hlines(0.05, -0.5, len(plot_params.columns)*2, 'tab:orange')

ax[1].set_ylim(-1,1)



plt.show()

# %% [markdown]
# # Mixed effects model

# %%
data = load_data('all')
all_data = pd.DataFrame()


for i, subject in enumerate(data):
    subject['subj'] = i
    subject['cluster'] = preds[i]
    
    all_data = all_data.append(subject)
all_data.index = np.arange(len(all_data))
for column in all_data.columns:
    if column in ['subj', 'cluster'] or abs(all_data[column]).sum()==0:
        continue
    all_data[column] = zscore(all_data[column], nan_policy='omit')

all_data0 = all_data[all_data['cluster']==0]
all_data1 = all_data[all_data['cluster']==1]
all_data0.index = np.arange(len(all_data0))
all_data1.index = np.arange(len(all_data1))

# %%
cols = ['bet','d_market_belief','rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret']
behav=all_data.dropna()
for column in behav.columns:
    if abs(behav[column]).sum()>0 and column not in ['cluster', 'subj']:
        behav[column] = zscore(behav[column], nan_policy='omit')

poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
Xb = behav[cols]
y_true = behav['d_bet'].values
X_tr = poly.fit_transform(Xb)
cs = poly.get_feature_names()

for i, c in enumerate(cs[:len(cols)]):
    cs = [x.replace(c, cols[i]) for x in cs]
    cs = [x.replace(' ', '*') for x in cs]
    rel_cs = [x for x in cs if ('bet' in x) or (not '*' in x)]
    
Xt = pd.DataFrame(X_tr,columns=cs)[rel_cs]
# mod = sm.MixedLM(y_true, Xt, groups=behav['subj'])
mod = sm.OLS(y_true, Xt)
result = mod.fit()
result.summary()
# Out:
# <ipython-input-102-bae8fe5179d6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   behav[column] = zscore(behav[column], nan_policy='omit')
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.195
# Model:                            OLS   Adj. R-squared (uncentered):              0.191
# Method:                 Least Squares   F-statistic:                              54.17
# Date:                Thu, 07 Apr 2022   Prob (F-statistic):                   1.32e-107
# Time:                        14:46:47   Log-Likelihood:                         -3241.0
# No. Observations:                2473   AIC:                                      6504.
# Df Residuals:                    2462   BIC:                                      6568.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# bet                           -0.3088      0.028    -11.004      0.000      -0.364      -0.254
# d_market_belief                0.2010      0.035      5.817      0.000       0.133       0.269
# rejoice                       -0.0275      0.038     -0.720      0.472      -0.103       0.047
# regret                         0.0071      0.041      0.175      0.861      -0.073       0.087
# counterfactual_rejoice         0.1205      0.046      2.604      0.009       0.030       0.211
# counterfactual_regret          0.0494      0.041      1.218      0.223      -0.030       0.129
# bet*d_market_belief            0.0168      0.034      0.501      0.616      -0.049       0.083
# bet*rejoice                    0.0197      0.032      0.620      0.535      -0.043       0.082
# bet*regret                    -0.0682      0.037     -1.860      0.063      -0.140       0.004
# bet*counterfactual_rejoice     0.0230      0.029      0.802      0.423      -0.033       0.079
# bet*counterfactual_regret     -0.0414      0.028     -1.484      0.138      -0.096       0.013
# ==============================================================================
# Omnibus:                      101.665   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              282.031
# Skew:                          -0.147   Prob(JB):                     5.72e-62
# Kurtosis:                       4.628   Cond. No.                         7.30
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## only random intercepts

# %%
md = smf.mixedlm('d_bet ~ 0 + bet + d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_regret + counterfactual_rejoice', all_data0, missing = "drop", groups=all_data0["subj"])
mdf = md.fit(reml = False, method = 'BFGS')
print(mdf.summary())
print('BIC: ' + str(mdf.bic))
params0 = mdf.params
params0['BIC'] = mdf.bic
err1 = mdf.bse_fe

md = smf.mixedlm('d_bet ~ 0 + bet + d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_regret + counterfactual_rejoice', all_data1, missing = "drop", groups=all_data1["subj"])
mdf = md.fit(reml = False, method = 'BFGS')
print(mdf.summary())
print('BIC: ' + str(mdf.bic))
params1 = mdf.params
params1['BIC'] = mdf.bic
err2 = mdf.bse_fe
# all_params = all_params.append(params, ignore_index=True)
# Out:
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:                MixedLM    Dependent Variable:    d_bet
# No. Observations:     1428       Method:                ML
# No. Groups:           12         Scale:                 0.6861
# Min. group size:      119        Log-Likelihood:        -1775.3204
# Max. group size:      119        Converged:             Yes
# Mean group size:      119.0
# ------------------------------------------------------------------
#                        Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------
# bet                    -0.568    0.037 -15.371 0.000 -0.640 -0.495
# d_market_belief         0.142    0.040   3.524 0.000  0.063  0.221
# d_market_uncertainty    0.017    0.029   0.571 0.568 -0.040  0.074
# regret                 -0.085    0.034  -2.484 0.013 -0.153 -0.018
# rejoice                -0.007    0.027  -0.262 0.793 -0.059  0.045
# counterfactual_regret   0.111    0.035   3.144 0.002  0.042  0.179
# counterfactual_rejoice  0.029    0.033   0.886 0.376 -0.035  0.094
# Group Var               0.111    0.060
# ==================================================================
#
# BIC: 3616.017036051992
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:                 MixedLM    Dependent Variable:    d_bet
# No. Observations:      688        Method:                ML
# No. Groups:            6          Scale:                 0.9158
# Min. group size:       99         Log-Likelihood:        -956.6266
# Max. group size:       119        Converged:             Yes
# Mean group size:       114.7
# ------------------------------------------------------------------
#                        Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------
# bet                    -0.575    0.050 -11.455 0.000 -0.674 -0.477
# d_market_belief         0.332    0.069   4.803 0.000  0.197  0.468
# d_market_uncertainty   -0.036    0.031  -1.175 0.240 -0.097  0.024
# regret                 -0.149    0.084  -1.775 0.076 -0.314  0.016
# rejoice                 0.220    0.063   3.512 0.000  0.097  0.343
# counterfactual_regret   0.089    0.039   2.251 0.024  0.011  0.166
# counterfactual_rejoice  0.178    0.045   3.980 0.000  0.090  0.265
# Group Var               0.270    0.173
# ==================================================================
#
# BIC: 1972.057370682073

# %%
ax = pd.concat([params0,params1], axis=1).drop(['BIC'] + [x for x in pd.concat([params0,params1], axis=1).T.columns if 'Var' in x]).plot(kind='bar', color=two_colors, yerr=[err1, err2])
plt.ylabel('coeff')
plt.xticks(rotation=45, ha="right")
plt.legend(['c1', 'c2'])
ax.figure.set_dpi(400)
plt.show()

# %% [markdown]
# ## random intercepts and random slopes

# %%
vc_formula = {
    'd_market_belief': ' d_market_belief ',
    'd_market_uncertainty': ' d_market_uncertainty',
    'regret': 'regret',
    'rejoice': ' rejoice',
    'counterfactual_regret': ' counterfactual_regret',
    'counterfactual_rejoice': ' counterfactual_rejoice',
    'bet': 'bet'}

md = smf.mixedlm("d_bet ~ 0 + bet + d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_regret + counterfactual_rejoice", 
                             all_data0, 
                             vc_formula=vc_formula, 
                             missing = "drop", 
                             groups='subj')
mdf = md.fit(reml = False, method = 'BFGS')
print(mdf.summary())
print('BIC: ' + str(mdf.bic/(preds==0).sum()))
params0 = mdf.params
params0['BIC'] = mdf.bic
resid0 = abs(mdf.resid).sum()/len(mdf.resid)

md = smf.mixedlm("d_bet ~ 0 + bet + d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_regret + counterfactual_rejoice", 
                             all_data1, 
                             vc_formula=vc_formula, 
                             missing = "drop", 
                             groups='subj')
mdf = md.fit(reml = False, method = 'BFGS')
print(mdf.summary())
print('BIC: ' + str(mdf.bic/(preds==1).sum()))
params1 = mdf.params
params1['BIC'] = mdf.bic
resid1 = abs(mdf.resid).sum()/len(mdf.resid)
all_params = all_params.append(params, ignore_index=True)
# Out:
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 3.678507
#   warnings.warn(msg, ConvergenceWarning)
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                 MixedLM     Dependent Variable:     d_bet
# No. Observations:      1785        Method:                 ML
# No. Groups:            15          Scale:                  0.5034
# Min. group size:       119         Log-Likelihood:         -2012.0838
# Max. group size:       119         Converged:              No
# Mean group size:       119.0
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# bet                        -0.670    0.084 -8.006 0.000 -0.833 -0.506
# d_market_belief             0.203    0.076  2.672 0.008  0.054  0.351
# d_market_uncertainty        0.034    0.038  0.880 0.379 -0.041  0.108
# regret                     -0.044    0.030 -1.467 0.142 -0.103  0.015
# rejoice                    -0.023    0.036 -0.628 0.530 -0.094  0.048
# counterfactual_regret      -0.012    0.038 -0.316 0.752 -0.087  0.063
# counterfactual_rejoice     -0.008    0.071 -0.117 0.907 -0.148  0.131
# bet Var                     0.084    0.046
# counterfactual_regret Var   0.006    0.009
# counterfactual_rejoice Var  0.028    0.033
# d_market_belief Var         0.069    0.036
# d_market_uncertainty Var    0.013    0.012
# regret Var                  0.000    0.007
# rejoice Var                 0.011    0.010
# =====================================================================
#
# BIC: 295.4625167365802
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                  MixedLM     Dependent Variable:     d_bet
# No. Observations:       688         Method:                 ML
# No. Groups:             6           Scale:                  0.7750
# Min. group size:        99          Log-Likelihood:         -922.3808
# Max. group size:        119         Converged:              No
# Mean group size:        114.7
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# bet                        -0.556    0.100 -5.580 0.000 -0.752 -0.361
# d_market_belief             0.344    0.112  3.062 0.002  0.124  0.564
# d_market_uncertainty       -0.047    0.038 -1.233 0.218 -0.122  0.028
# regret                     -0.096    0.167 -0.578 0.563 -0.423  0.231
# rejoice                     0.176    0.166  1.058 0.290 -0.150  0.502
# counterfactual_regret       0.125    0.075  1.651 0.099 -0.023  0.272
# counterfactual_rejoice      0.196    0.059  3.354 0.001  0.082  0.311
# bet Var                     0.041    0.035
# counterfactual_regret Var   0.022    0.030
# counterfactual_rejoice Var  0.003    0.007
# d_market_belief Var         0.046    0.053
# d_market_uncertainty Var    0.001
# regret Var                  0.069    0.164
# rejoice Var                 0.081    0.124
# =====================================================================
#
# BIC: 277.53835338465893
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 12.429778
#   warnings.warn(msg, ConvergenceWarning)
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)

# %%
fig, ax = plt.subplots(figsize=(figwidth, 4.5), dpi=300)
pd.concat([params0,params1], axis=1).drop(['BIC'] + [x for x in pd.concat([params0,params1], axis=1).T.columns if 'Var' in x]).plot(kind='bar', color=two_colors, ax=ax)
plt.ylabel('coeff')
plt.xticks(rotation=45, ha="right")
plt.legend(['c1', 'c2'])
ax.figure.set_dpi(400)

ins = ax.inset_axes([0.9,0.1,0.1,0.3])
ins.bar([0,1], [resid0,resid1], tick_label=['c1','c2'], color=two_colors)
ins.set_ylabel('mean abs. residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## random intercepts and random slopes and covariances

# %%
md = sm.MixedLM.from_formula("d_bet ~  d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_regret + counterfactual_rejoice", 
                             all_data, 
                             re_formula='d_market_belief + d_market_uncertainty + regret + rejoice + counterfactual_regret + counterfactual_rejoice', 
                             missing = "drop", 
                             groups=all_data["subj"])

mdf = md.fit(reml = False, method = 'BFGS')
print(mdf.summary(alpha=0.05))
print('BIC: ' + str(mdf.bic))
params = mdf.params
params['BIC'] = mdf.bic
all_params = all_params.append(params, ignore_index=True)
# Out:
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 78.982961
#   warnings.warn(msg, ConvergenceWarning)
# /home/lu/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                         MixedLM             Dependent Variable:             d_bet
# No. Observations:              2473                Method:                         ML
# No. Groups:                    21                  Scale:                          0.7289
# Min. group size:               99                  Log-Likelihood:                 -3191.6239
# Max. group size:               119                 Converged:                      No
# Mean group size:               117.8
# ---------------------------------------------------------------------------------------------
#                                                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                          -0.010    0.031 -0.315 0.753 -0.071  0.051
# d_market_belief                                     0.235    0.072  3.267 0.001  0.094  0.376
# d_market_uncertainty                                0.018    0.032  0.559 0.576 -0.044  0.080
# regret                                             -0.224    0.068 -3.294 0.001 -0.357 -0.091
# rejoice                                            -0.126    0.037 -3.441 0.001 -0.197 -0.054
# counterfactual_regret                               0.201    0.059  3.406 0.001  0.085  0.316
# counterfactual_rejoice                              0.243    0.061  3.958 0.000  0.122  0.363
# Group Var                                           0.011    0.009
# Group x d_market_belief Cov                         0.002    0.012
# d_market_belief Var                                 0.080    0.038
# Group x d_market_uncertainty Cov                    0.009    0.009
# d_market_belief x d_market_uncertainty Cov          0.003    0.017
# d_market_uncertainty Var                            0.008    0.004
# Group x regret Cov                                  0.012    0.013
# d_market_belief x regret Cov                       -0.000    0.025
# d_market_uncertainty x regret Cov                   0.009    0.018
# regret Var                                          0.038    0.039
# Group x rejoice Cov                                 0.003    0.006
# d_market_belief x rejoice Cov                      -0.009    0.013
# d_market_uncertainty x rejoice Cov                  0.003    0.009
# regret x rejoice Cov                                0.005    0.010
# rejoice Var                                         0.011    0.008
# Group x counterfactual_regret Cov                   0.007    0.012
# d_market_belief x counterfactual_regret Cov         0.038    0.023
# d_market_uncertainty x counterfactual_regret Cov    0.005    0.007
# regret x counterfactual_regret Cov                  0.004    0.021
# rejoice x counterfactual_regret Cov                -0.002    0.010
# counterfactual_regret Var                           0.039    0.019
# Group x counterfactual_rejoice Cov                  0.001    0.009
# d_market_belief x counterfactual_rejoice Cov        0.031    0.021
# d_market_uncertainty x counterfactual_rejoice Cov   0.002    0.008
# regret x counterfactual_rejoice Cov                 0.003    0.015
# rejoice x counterfactual_rejoice Cov               -0.004    0.008
# counterfactual_regret x counterfactual_rejoice Cov  0.022    0.015
# counterfactual_rejoice Var                          0.024    0.020
# =============================================================================================
#
# BIC: 6664.5225453376215

# %%
ax = params.drop(['BIC']).T.plot(kind='bar')
plt.ylabel('coeff')
# plt.xticks(rotation=45, ha="right")
ax.figure.set_dpi(400)
plt.show()

# %%
ax = all_params[['d_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret', 'prev_bet']].T.plot(kind='bar')
plt.ylabel('coeff')
plt.xticks(rotation=45, ha="right")
plt.legend(labels=['Only Intercept','Intercept + Var','Intercept + Var incl. prev bet','Intercept + Var+ Cov'])
ax.figure.set_dpi(400)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-dc4ef135e138> in <module>
# ----> 1 ax = all_params[['d_market_belief', 'd_market_uncertainty', 'rejoice', 'regret', 'counterfactual_rejoice', 'counterfactual_regret', 'prev_bet']].T.plot(kind='bar')
#       2 plt.ylabel('coeff')
#       3 plt.xticks(rotation=45, ha="right")
#       4 plt.legend(labels=['Only Intercept','Intercept + Var','Intercept + Var incl. prev bet','Intercept + Var+ Cov'])
#       5 ax.figure.set_dpi(400)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5780             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5781
# -> 5782         self._raise_if_missing(keyarr, indexer, axis_name)
#    5783
#    5784         keyarr = self.take(indexer)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5843
#    5844             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845             raise KeyError(f"{not_found} not in index")
#    5846
#    5847     @overload
#
# KeyError: "['prev_bet'] not in index"

# %%
ax = sns.barplot(['Only Intercept','Intercept + Var', 'Intercept + Var incl. prev bet', 'Intercept + Var+ Cov'], all_params['BIC'])
# plt.ylabel('coeff')
plt.xticks(rotation=45, ha="right")
ax.figure.set_dpi(400)
plt.ylim(20000)
plt.show()

# %% [markdown]
# # Check for state dependency

# %%
data = load_data('all')
params = ['d_market_belief', 
          'd_market_uncertainty', 
          'rejoice', 
          'regret', 
          'counterfactual_rejoice', 
          'counterfactual_regret']

ps = np.zeros((len(params), len(data)))
coeffs = np.zeros((len(params), len(data)))

for i, param in enumerate(params):
    for j, subject in enumerate(data):

        c_data = generate_subject_table(subject)
        bets = np.array(c_data.bet)
        d_bets = np.array(c_data.d_bet)


        for column in c_data.columns:
            if abs(c_data[column]).sum()>0:
                c_data[column] = zscore(c_data[column], nan_policy='omit')

        md = sm.OLS.from_formula('d_bet ~0 + ' + param, c_data, missing='drop')
        result = md.fit()

        indep_var = c_data[param]*c_data['prev_bet']*result.params[param] 
        df = pd.DataFrame({'resid': result.resid, 'indep_var': indep_var })

        new_md = sm.OLS.from_formula('resid ~ 0+ indep_var', df, missing='drop')
        new_result = new_md.fit()
        
        coeffs[i, j] = new_result.params[0]
        ps[i, j] = new_result.pvalues[0]

# %%
df_coeffs = pd.DataFrame(coeffs.T, columns=params)
df_ps = pd.DataFrame(ps.T, columns=params)

plt.figure(dpi=400)
props = {'color': 'tab:blue'}
df_coeffs.boxplot(notch=True, showfliers=False, positions=np.arange(len(df_coeffs.columns))*2-0.4, widths=.6, medianprops=props, capprops=props, whis=[5,95])

props = {'color': 'tab:orange'}
df_ps.boxplot(notch=True, showfliers=False, positions=np.arange(len(df_ps.columns))*2+0.4, widths=.6, boxprops=props, medianprops=props, whiskerprops=props, capprops=props, whis=[5,95])

plt.grid(False)
plt.hlines(0, -0.5, len(df_ps.columns)*2, 'k', linestyles='dashed', linewidth=.7)
plt.xticks(rotation=45, ha="right")
plt.xticks(np.arange(len(df_ps.columns))*2, df_ps.columns)
plt.legend(handles=[mpatches.Patch(color='tab:blue', label='coefficient'), mpatches.Patch(color='tab:orange', label='p_value')])
plt.hlines(0.05, -0.5, len(df_ps.columns)*2, 'tab:orange', linewidth=.7)

plt.ylim(-2,2)
plt.show()
